# %% [markdown]
# <a href="https://colab.research.google.com/github/Vattikolla/FMML-2024/blob/main/Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2025-03-13 15:49:48--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   134MB/s    in 0.5s
#
# 2025-03-13 15:49:50 (134 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 5650   1505.07008v1  This contribution summarizes the results on th...  stat
# 16654  1704.07986v1  We present in this paper our approach for mode...    cs
# 23163   0806.1984v1  We propose a robust classification algorithm f...    cs
# 37418  1706.03661v2  This paper introduces a cognitive architecture...    cs
# 26349  1610.00382v1  Near-infrared gray images captured together wi...    cs
# ...             ...                                                ...   ...
# 7851   1803.08367v1  Deep neural networks are often trained in the ...  stat
# 5288    1209.5477v2  In Natural Language Processing (NLP) tasks, da...  stat
# 3785   1508.05514v1  We propose a greedy mixture reduction algorith...  stat
# 20371  1511.04326v1  We present the results of the ICON Challenge o...    cs
# 11769  1611.08372v1  The Schatten-$p$ norm ($0<p<1$) has been widel...  stat
#
#                                                    title  year  \
# 5650   An Overview of the Asymptotic Performance of t...  2015
# 16654  Other Topics You May Also Agree or Disagree: M...  2017
# 23163  Classification of curves in 2D and 3D via affi...  2008
# 37418  DAC-h3: A Proactive Robot Cognitive Architectu...  2017
# 26349  Near-Infrared Coloring via a Contrast-Preservi...  2016
# ...                                                  ...   ...
# 7851    Gradient Descent Quantizes ReLU Network Features  2018
# 5288   Optimal Weighting of Multi-View Data with Low ...  2012
# 3785   Gaussian Mixture Reduction Using Reverse Kullb...  2015
# 20371              ICON Challenge on Algorithm Selection  2015
# 11769  A Unified Convex Surrogate for the Schatten-$p...  2016
#
#                                                 keywords
# 5650   [contribution, summarizes, asymptotic, perform...
# 16654  [preferences, partnership, knowledge, detectio...
# 23163  [classification, algorithm, transformations, s...
# 37418  [introduces, cognitive, architecture, proactiv...
# 26349  [corresponding, restoration, classification, i...
# ...                                                  ...
# 7851   [parametrized, parameters, understanding, conv...
# 5288   [processing, following, properties, successful...
# 3785   [reduction, algorithm, components, divergence,...
# 20371  [challenge, algorithm, selection, challenge, a...
# 11769  [approximating, decomposition, iteration, sati...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 5650     [contribution, summarizes, asymptotic, perform...
# 16654    [preferences, partnership, knowledge, detectio...
# 23163    [classification, algorithm, transformations, s...
# 37418    [introduces, cognitive, architecture, proactiv...
# 26349    [corresponding, restoration, classification, i...
#                                ...
# 21668    [filtering, algorithms, operating, reproducing...
# 6080     [explanation, explaining, classifiers, describ...
# 3280     [selection, information, increasingly, applica...
# 10324    [prediction, collections, connected, predictio...
# 37892    [estimation, distributions, determining, strat...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8767 words.
# Out of those 4590 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="b5aecfe6-da61-4845-a6fb-bcb98d9c0280" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b5aecfe6-da61-4845-a6fb-bcb98d9c0280")) {                    Plotly.newPlot(                        "b5aecfe6-da61-4845-a6fb-bcb98d9c0280",                        [{"x":["performance","presented","algorithms","contribution","asymptotic","expressions","summarizes","algorithm","collection","campaigns","including","partnership","electoral","successfully","factorization","experimental","formalize","predictions","recommendation","demonstrate","detection","applications","knowledge","preferences","representing","abstracts","statements","representations","linguistic","predicting","completely","inductive","invariants","independent","transformations","equivalent","differential","transformation","introduction","classically","signatures","extracted","comparison","equivalence","sensitive","parameterization","application","signature","classification","fragments","euclidean","occlusions","variation","introduced","therefore","robustness","establish","initiative","exploration","narrative","interaction","cognitive","grounding","framework","environment","manipulation","perceptual","experience","integrates","biologically","introduces","abilities","realistic","experiments","proactive","architecture","originate","capabilities","transfers","structure","discrepancy","appearance","preserving","brightness","restoration","unrealistic","discrepancies","corresponding","contrasts","denoising","especially","linguistically","realization","generation","situation","efficient","development","components","increased","flexibility","techniques","connection","currently","perspective","ontologies","associated","generating","resources","orthogonal","motivated","variations","adaptation","canonical","selection","generalization","contributions","introduce","similarity","benchmarks","hierarchical","retrieval","bidirectional","regularized","conjunction","computationally","representation","correlation","increasing","approximates","weighting","stability","filtering","multimodal","asymmetric","achieving","distribution","embedding","sentences","phenomenon","represented","probability","situations","information","ignorance","prediction","uncertainty","sometimes","noninformative","posterior","additional","synthesize","specifically","considerably","interesting","recognition","annotation","synthesis","artificial","attribute","augmentation","synthesized","particularly","primarily","available","attributed","implement","annotated","outperforms","feedforward","consistently","difficult","relations","languages","discourse","applicable","configured","inferring","continuous","controlled","significant","essential","practitioners","practical","squeezing","considered","overfitting","validation","challenging","elimination","confidence","arbitrary","dependence","experimentally","guarantees","identification","promising","sequential","intervals","procedure","complexity"],"y":[897,178,605,57,15,37,6,817,69,3,236,1,2,78,35,363,11,88,34,592,375,422,368,31,72,5,15,218,79,71,42,21,3,127,41,49,32,60,31,3,8,114,142,14,60,9,227,10,476,11,37,14,64,130,137,106,49,9,79,12,75,53,12,539,118,13,28,27,25,18,68,20,74,598,2,258,2,52,7,349,7,84,45,9,12,6,2,136,8,44,106,8,8,127,25,401,140,108,38,27,375,37,63,66,22,115,86,73,20,69,74,78,23,159,140,49,352,145,94,110,104,22,31,20,90,359,76,112,8,26,30,55,30,16,81,240,113,66,21,82,176,56,710,2,201,79,27,1,41,123,17,180,25,61,363,66,59,139,48,23,25,81,21,278,7,75,89,261,16,35,130,107,90,22,51,5,24,111,36,248,60,7,132,1,128,25,50,259,11,31,82,19,57,57,108,93,75,11,132,236],"type":"bar"},{"x":["performance","presented","algorithms","contribution","asymptotic","expressions","summ ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4590,), (4590, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.81

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.6296296296296298);'>Bidirectional</span> <span style=''>Multirate</span> <span style='background-color:rgba(0, 255, 0, 0.31972789115646255);'>Reconstruction</span> <span style=''>for</span> <span style=''>Temporal</span> <span style=''>Modeling</span> <span style=''>in</span> <span style=''>Videos</span> <br/><br/><span style=''>Despite</span> <span style=''>the</span> <span style=''>recent</span> <span style=''>success</span> <span style=''>of</span> <span style=''>neural</span> <span style=''>networks</span> <span style=''>in</span> <span style=''>image</span> <span style=''>feature</span> <span style=''>learning</span> <span style=''>a</span> <span style=''>major</span> <span style=''>problem</span> <span style=''>in</span> <span style=''>the</span> <span style=''>video</span> <span style=''>domain</span> <span style=''>is</span> <span style=''>the</span> <span style=''>lack</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>sufficient</span> <span style=''>labeled</span> <span style=''>data</span> <span style=''>for</span> <span style=''>learning</span> <span style=''>to</span> <span style=''>model</span> <span style=''>temporal</span> <span style='background-color:rgba(0, 255, 0, 0.3111726685133887);'>information</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>unsupervised</span> <span style=''>temporal</span> <span style=''>modeling</span> <span style=''>method</span> <span style=''>that</span> <span style=''>learns</span> <span style=''>from</span> <span style=''>untrimmed</span> <span style=''>videos</span> <span style=''>The</span> <span style=''>speed</span> <span style=''>of</span> <span style=''>motion</span> <span style=''>varies</span> <span style='background-color:rgba(0, 255, 0, 0.6000000000000001);'>constantly</span> <span style=''>eg</span> <span style=''>a</span> <span style=''>man</span> <span style=''>may</span> <span style=''>run</span> <span style=''>quickly</span> <span style=''>or</span> <span style=''>slowly</span> <span style=''>We</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>therefore</span> <span style=''>train</span> <span style=''>a</span> <span style=''>Multirate</span> <span style=''>Visual</span> <span style='background-color:rgba(0, 255, 0, 0.45116279069767445);'>Recurrent</span> <span style=''>Model</span> <span style=''>(MVRM)</span> <span style=''>by</span> <span style=''>encoding</span> <span style=''>frames</span> <span style=''>of</span> <span style=''>a</span> <span style=''>clip</span> <span style=''>with</span> <span style='background-color:rgba(0, 255, 0, 0.32811140121845084);'>different</span> <span style='background-color:rgba(255, 0, 0, 0.4054054054054053);'>intervals</span> <span style=''>This</span> <span style=''>learning</span> <span style=''>process</span> <span style=''>makes</span> <span style=''>the</span> <span style=''>learned</span> <span style=''>model</span> <span style=''>more</span> <span style=''>capable</span> <span style=''>of</span> <span style=''>dealing</span> <span style=''>with</span> <span style=''>motion</span> <span style=''>speed</span> <span style=''>variance</span> <span style=''>Given</span> <span style=''>a</span> <span style=''>clip</span> <span style=''>sampled</span> <span style=''>from</span> <span style=''>a</span> <span style=''>video</span> <span style=''>we</span> <span style=''>use</span> <span style=''>its</span> <span style=''>past</span> <span style=''>and</span> <span style=''>future</span> <span style='background-color:rgba(0, 255, 0, 0.894736842105263);'>neighboring</span> <span style=''>clips</span> <span style=''>as</span> <span style=''>the</span> <span style=''>temporal</span> <span style=''>context</span> <span style=''>and</span> <span style='background-color:rgba( ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>The</span> <span style=''>Discrete</span> <span style=''>Infinite</span> <span style=''>Logistic</span> <span style=''>Normal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Distribution</span> <br/><br/><span style=''>We</span> <span style=''>present</span> <span style=''>the</span> <span style=''>discrete</span> <span style=''>infinite</span> <span style=''>logistic</span> <span style=''>normal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distribution</span> <span style=''>(DILN)</span> <span style=''>a</span> <span style=''>Bayesian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>nonparametric</span> <span style=''>prior</span> <span style=''>for</span> <span style=''>mixed</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>membership</span> <span style=''>models</span> <span style=''>DILN</span> <span style=''>is</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generalization</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>hierarchical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Dirichlet</span> <span style=''>process</span> <span style=''>(HDP)</span> <span style=''>that</span> <span style=''>models</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>correlation</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structure</span> <span style=''>between</span> <span style=''>the</span> <span style=''>weights</span> <span style=''>of</span> <span style=''>the</span> <span style=''>atoms</span> <span style=''>at</span> <span style=''>the</span> <span style=''>group</span> <span style=''>level</span> <span style=''>We</span> <span style=''>derive</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>representation</span> <span style=''>of</span> <span style=''>DILN</span> <span style=''>as</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>normalized</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>collection</span> <span style=''>of</span> <span style=''>gamma</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distributed</span> <span style=''>random</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variables</span> <span style=''>and</span> <span style=''>study</span> <span style=''>its</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>properties</span> <span style=''>We</span> <span style=''>consider</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>applications</span> <span style=''>to</span> <span style=''>topic</span> <span style=''>modeling</span> <span style=''>and</span> <span style=''>derive</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variational</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approximate</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>posterior</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style=''>We</span> <span style=''>study</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>empirical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performance</span> <span style=''>of</span> <span style=''>the</span> <span style=''>DILN</span> <span style=''>topic</span> <span style=''>model</span> <span style=''>on</span> <span style=''>four</span> <span style=''>corpora</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>comparing</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performance</span> <span style=''>with</span> <span style=''>the</span> <span style=''>HDP</span> <span style=''>and</span> <span style ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Learning</span> <span style=''>Gaussian</span> <span style=''>Networks</span> <br/><br/><span style=''>We</span> <span style=''>describe</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>for</span> <span style=''>learning</span> <span style=''>Bayesian</span> <span style=''>networks</span> <span style=''>from</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.30769230769230776);'>combination</span> <span style=''>of</span> <span style=''>user</span> <span style='background-color:rgba(0, 255, 0, 0.3834586466165414);'>knowledge</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>statistical</span> <span style=''>data</span> <span style=''>The</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>have</span> <span style=''>two</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>components</span> <span style=''>a</span> <span style=''>scoring</span> <span style=''>metric</span> <span style=''>and</span> <span style=''>a</span> <span style=''>search</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>procedure</span> <span style=''>The</span> <span style=''>scoring</span> <span style=''>metric</span> <span style=''>takes</span> <span style=''>a</span> <span style=''>network</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structure</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>statistical</span> <span style=''>data</span> <span style=''>and</span> <span style=''>a</span> <span style=''>users</span> <span style=''>prior</span> <span style='background-color:rgba(0, 255, 0, 0.3834586466165414);'>knowledge</span> <span style=''>and</span> <span style=''>returns</span> <span style=''>a</span> <span style=''>score</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>proportional</span> <span style=''>to</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.6);'>posterior</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probability</span> <span style=''>of</span> <span style=''>the</span> <span style=''>network</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structure</span> <span style=''>given</span> <span style=''>the</span> <span style=''>data</span> <span style=''>The</span> <span style=''>search</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>procedure</span> <span style='background-color:rgba(0, 255, 0, 0.5757575757575758);'>generates</span> <span style=''>networks</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.4104046242774568);'>evaluation</span> <span style=''>by</span> <span style=''>the</span> <span style=''>scoring</span> <span style=''>metric</span> <span style=''>Previous</span> <span style=''>work</span> <span style=''>has</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>concentrated</span> <span style=''>on</span> <span style=''>metrics</span> <span style=''>for</span> <span style=''>domains</span> <span style='background-color:rgba(0, 255, 0, 0.3181818181818181);'>containing</span> <span style=''>only</span> <span style=''>discrete</span> <span style='background-color:rgba(255, 0, 0, 0.3459715639810426);'>variables</span> <span style=''>under</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>assumption</span> <span style=''>that</span> <span style=''>data</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>represents</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.4166666666666667);'>multinomial</span> <span style=''>sample</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>extend</span> <span style=''>this</span> <span style=''>work</span> <span style='background-color:rgba(0, 255, 0, 0.3846153846153846);'>developing</span> <span style=''>scoring</span> <span styl ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Dynamic</span> <span style=''>Word</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Embeddings</span> <br/><br/><span style=''>We</span> <span style=''>present</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probabilistic</span> <span style=''>language</span> <span style=''>model</span> <span style=''>for</span> <span style=''>time</span> <span style=''>stamped</span> <span style=''>text</span> <span style=''>data</span> <span style=''>which</span> <span style=''>tracks</span> <span style=''>the</span> <span style=''>semantic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>evolution</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>individual</span> <span style=''>words</span> <span style=''>over</span> <span style=''>time</span> <span style=''>The</span> <span style=''>model</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>represents</span> <span style=''>words</span> <span style=''>and</span> <span style=''>contexts</span> <span style=''>by</span> <span style=''>latent</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>trajectories</span> <span style=''>in</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>embedding</span> <span style=''>space</span> <span style=''>At</span> <span style=''>each</span> <span style=''>moment</span> <span style=''>in</span> <span style=''>time</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>embedding</span> <span style=''>vectors</span> <span style=''>are</span> <span style=''>inferred</span> <span style=''>from</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probabilistic</span> <span style=''>version</span> <span style=''>of</span> <span style=''>word2vec</span> <span style=''>Mikolov</span> <span style=''>et</span> <span style=''>al</span> <span style=''>2013</span> <span style=''>These</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>embedding</span> <span style=''>vectors</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>connected</span> <span style=''>in</span> <span style=''>time</span> <span style=''>through</span> <span style=''>a</span> <span style=''>latent</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>diffusion</span> <span style=''>process</span> <span style=''>We</span> <span style=''>describe</span> <span style=''>two</span> <span style=''>scalable</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variational</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithms</span> <span style=''>skip</span> <span style=''>gram</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>smoothing</span> <span style=''>and</span> <span style=''>skip</span> <span style=''>gram</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>filtering</span> <span style=''>that</span> <span style=''>allow</span> <span style=''>us</span> <span style=''>to</span> <span style=''>train</span> <span style=''>the</span> <span style=''>model</span> <span style=''>jointly</span> <span style=''>over</span> <span style=''>all</span> <span style=''>times</span> <span style=''>thus</span> <span style=''>learning</span> <span style=''>on</span> <span style=''>all</span> <span style=''>data</span> <span style=''>while</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>simultaneously</span> <span style=''>allowing</span> <span style=''>word</span> <span style=''>and</span> <span style=''>context</span> <span style=''>vectors</span> <span style=''>to</span> <span style=''>drift</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Experimental</span> <span style=''>results</span> <span style=''>on</span> <span style=''>three</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>different</span> <span style=' ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	representation (0.12821428571428573)
# 	experimental (0.12964285714285714)
# 	knowledge (0.13142857142857142)
# 	architecture (0.09214285714285714)
# 	segmentation (0.07535714285714286)
# 	information (0.25357142857142856)
# 	different (0.2725)
# 	convolutional (0.12964285714285714)
# 	detection (0.13392857142857142)
# 	recognition (0.12964285714285714)
#
# Some Statistics words are:
# 	stochastic (0.14)
# 	variables (0.142)
# 	estimation (0.1635)
# 	distribution (0.181)
# 	algorithm (0.3915)
# 	statistical (0.164)
# 	theoretical (0.155)
# 	regression (0.1745)
# 	dimensional (0.196)
# 	inference (0.215)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="417c34f4-748e-47f0-a531-e337d8150933" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("417c34f4-748e-47f0-a531-e337d8150933")) {                    Plotly.newPlot(                        "417c34f4-748e-47f0-a531-e337d8150933",                        [{"x":["performance","presented","algorithms","contribution","asymptotic","expressions","summarizes","algorithm","collection","campaigns","including","partnership","electoral","successfully","factorization","experimental","formalize","predictions","recommendation","demonstrate","detection","applications","knowledge","preferences","representing","abstracts","statements","representations","linguistic","predicting","completely","inductive","invariants","independent","transformations","equivalent","differential","transformation","introduction","classically","signatures","extracted","comparison","equivalence","sensitive","parameterization","application","signature","classification","fragments","euclidean","occlusions","variation","introduced","therefore","robustness","establish","initiative","exploration","narrative","interaction","cognitive","grounding","framework","environment","manipulation","perceptual","experience","integrates","biologically","introduces","abilities","realistic","experiments","proactive","architecture","originate","capabilities","transfers","structure","discrepancy","appearance","preserving","brightness","restoration","unrealistic","discrepancies","corresponding","contrasts","denoising","especially","linguistically","realization","generation","situation","efficient","development","components","increased","flexibility","techniques","connection","currently","perspective","ontologies","associated","generating","resources","orthogonal","motivated","variations","adaptation","canonical","selection","generalization","contributions","introduce","similarity","benchmarks","hierarchical","retrieval","bidirectional","regularized","conjunction","computationally","representation","correlation","increasing","approximates","weighting","stability","filtering","multimodal","asymmetric","achieving","distribution","embedding","sentences","phenomenon","represented","probability","situations","information","ignorance","prediction","uncertainty","sometimes","noninformative","posterior","additional","synthesize","specifically","considerably","interesting","recognition","annotation","synthesis","artificial","attribute","augmentation","synthesized","particularly","primarily","available","attributed","implement","annotated","outperforms","feedforward","consistently","difficult","relations","languages","discourse","applicable","configured","inferring","continuous","controlled","significant","essential","practitioners","practical","squeezing","considered","overfitting","validation","challenging","elimination","confidence","arbitrary","dependence","experimentally","guarantees","identification","promising","sequential","intervals","procedure","complexity","outperform","resolution","summarizing","stochastic","sequentially","isolation","splitting","empirically","solutions","anticipate","important","understanding","generality","inhomogeneity","synthetic","objectives","histogram","discriminating","theoretical","theoretically","essentially","previously","practically","discovered","clustering","illustrate","disciplines","explaining","limitations","equalization","artifacts","implicitly","different","principled","conditions","automatically","predictors","conformal","unconditional","satisfying","modifications","exceeding","conditional","demonstrated","dimensional","strengths","estimates","parameter","maximization","discussed","historical","optimization","inference","challenges","combination","defe ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	inhomogeneity
# 	offensive
# 	transformative
# 	chemception
# 	compounds
# 	solvation
# 	composers
# 	blackwellisation
# 	distinguishability
# 	degenerate
# 	topography
# 	harvested
# 	penalization
# 	precludes
# 	schizophrenia
# 	psychiatric
# 	incapable
# 	calibrating
# 	logitboost
# 	submodels
# Some words which never appear in Statistics papers:
# 	electoral
# 	occlusions
# 	initiative
# 	narrative
# 	grounding
# 	proactive
# 	originate
# 	ignorance
# 	discourse
# 	configured
# 	surrounded
# 	entailment
# 	encodings
# 	categorised
# 	instagram
# 	assistants
# 	accelerator
# 	harmonics
# 	conceptualizations
# 	narratives

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.068425897514575e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7658333333333334
